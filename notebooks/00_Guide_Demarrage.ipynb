# %% [markdown]
# #  Guide de Démarrage - Système de Recommandation
#
# ## Bienvenue dans le TP !
#
# Ce notebook vous guidera pour bien démarrer le projet.

# %% [markdown]
# ##  Installation des Bibliothèques
#
# Commencez par installer toutes les bibliothèques nécessaires :

# %%
# Installation des bibliothèques (décommentez si nécessaire)
# !pip install pandas numpy matplotlib seaborn scikit-learn
# !pip install scipy mlflow fastapi uvicorn
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: pandas in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (1.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (1.15.2)
# Collecting mlflow
#   Downloading mlflow-3.5.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: fastapi in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (0.115.13)
# Collecting uvicorn
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scipy) (2.1.3)
# Collecting mlflow-skinny==3.5.1 (from mlflow)
#   Downloading mlflow_skinny-3.5.1-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.5.1 (from mlflow)
#   Downloading mlflow_tracing-3.5.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.17.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting cryptography<47,>=43.0.0 (from mlflow)
#   Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: matplotlib<4 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.10.0)
# Requirement already satisfied: pandas<3 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (2.2.3)
# Collecting pyarrow<22,>=4.0.0 (from mlflow)
#   Downloading pyarrow-21.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: scikit-learn<2 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (1.7.1)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading sqlalchemy-2.0.44-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting waitress<4 (from mlflow)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading cachetools-6.2.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.5.1->mlflow) (8.1.8)
# Collecting cloudpickle<4 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading databricks_sdk-0.71.0-py3-none-any.whl.metadata (39 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.5.1->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.5.1->mlflow) (6.32.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.5.1->mlflow) (2.11.1)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.5.1->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.5.1->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.5.1->mlflow) (2.32.3)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from mlflow-skinny==3.5.1->mlflow) (4.13.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from fastapi) (0.46.2)
# Requirement already satisfied: h11>=0.8 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from uvicorn) (0.14.0)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: colorama in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.5.1->mlflow) (0.4.6)
# Collecting cffi>=2.0.0 (from cryptography<47,>=43.0.0->mlflow)
#   Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\alecp\appdata\roaming\python\python312\site-packages (from docker<8,>=4.0.0->mlflow) (310)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow) (0.4.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Downloading greenlet-3.2.4-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: pycparser in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.22)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading google_auth-2.42.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (2025.1.31)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading mlflow-3.5.1-py3-none-any.whl (8.8 MB)
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/8.8 MB 7.4 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.0/8.8 MB 8.6 MB/s eta 0:00:01
#    -------------------------------- ------- 7.1/8.8 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.8/8.8 MB 9.6 MB/s eta 0:00:00
# Downloading mlflow_skinny-3.5.1-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------- -------- 1.8/2.3 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 8.8 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.5.1-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 9.3 MB/s eta 0:00:00
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading alembic-1.17.1-py3-none-any.whl (247 kB)
# Downloading cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -------------------- ------------------- 1.8/3.5 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 8.7 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading pyarrow-21.0.0-cp312-cp312-win_amd64.whl (26.2 MB)
#    ---------------------------------------- 0.0/26.2 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/26.2 MB 10.7 MB/s eta 0:00:03
#    ------ --------------------------------- 3.9/26.2 MB 10.2 MB/s eta 0:00:03
#    --------- ------------------------------ 6.0/26.2 MB 10.2 MB/s eta 0:00:02
#    ------------ --------------------------- 8.4/26.2 MB 10.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.5/26.2 MB 10.6 MB/s eta 0:00:02
#    ------------------- -------------------- 12.6/26.2 MB 10.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 14.9/26.2 MB 10.7 MB/s eta 0:00:02
#    -------------------------- ------------- 17.6/26.2 MB 11.0 MB/s eta 0:00:01
#    ------------------------------- -------- 20.7/26.2 MB 11.4 MB/s eta 0:00:01
#    ------------------------------------ --- 23.6/26.2 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  26.0/26.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 26.2/26.2 MB 11.5 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.44-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 10.9 MB/s eta 0:00:00
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.1-py3-none-any.whl (11 kB)
# Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading databricks_sdk-0.71.0-py3-none-any.whl (752 kB)
#    ---------------------------------------- 0.0/752.6 kB ? eta -:--:--
#    --------------------------------------- 752.6/752.6 kB 10.4 MB/s eta 0:00:00
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading greenlet-3.2.4-cp312-cp312-win_amd64.whl (299 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading google_auth-2.42.1-py2.py3-none-any.whl (222 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: zipp, waitress, sqlparse, smmap, pyasn1, pyarrow, opentelemetry-proto, Mako, itsdangerous, greenlet, graphql-core, cloudpickle, cffi, cachetools, blinker, uvicorn, sqlalchemy, rsa, pyasn1-modules, importlib_metadata, graphql-relay, gitdb, Flask, docker, cryptography, opentelemetry-api, graphene, google-auth, gitpython, Flask-CORS, alembic, opentelemetry-semantic-conventions, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.1 blinker-1.9.0 cachetools-6.2.1 cffi-2.0.0 cloudpickle-3.1.2 cryptography-46.0.3 databricks-sdk-0.71.0 docker-7.1.0 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.42.1 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 greenlet-3.2.4 importlib_metadata-8.7.0 itsdangerous-2.2.0 mlflow-3.5.1 mlflow-skinny-3.5.1 mlflow-tracing-3.5.1 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pyarrow-21.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1 smmap-5.0.2 sqlalchemy-2.0.44 sqlparse-0.5.3 uvicorn-0.38.0 waitress-3.0.2 zipp-3.23.0
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: joblib>=1.2.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scikit-surprise) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\alecp\appdata\local\programs\python\python312\lib\site-packages (from scikit-surprise) (1.15.2)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml): started
#   Building wheel for scikit-surprise (pyproject.toml): finished with status 'error'
# Failed to build scikit-surprise
#   error: subprocess-exited-with-error
#
#   × Building wheel for scikit-surprise (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [155 lines of output]
#       C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
#               Please use a simple string containing a SPDX expression for `project.license`. You can also use `project.license-files`. (Both options available on setuptools>=77.0.0).
#
#               By 2026-Feb-18, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         corresp(dist, value, root_dir)
#       C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:61: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: BSD License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         dist._finalize_license_expression()
#       C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: BSD License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-312\surprise
#       copying surprise\accuracy.py -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\builtin_datasets.py -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\dataset.py -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\dump.py -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\reader.py -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\trainset.py -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\utils.py -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\__init__.py -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\__main__.py -> build\lib.win-amd64-cpython-312\surprise
#       creating build\lib.win-amd64-cpython-312\surprise\model_selection
#       copying surprise\model_selection\search.py -> build\lib.win-amd64-cpython-312\surprise\model_selection
#       copying surprise\model_selection\split.py -> build\lib.win-amd64-cpython-312\surprise\model_selection
#       copying surprise\model_selection\validation.py -> build\lib.win-amd64-cpython-312\surprise\model_selection
#       copying surprise\model_selection\__init__.py -> build\lib.win-amd64-cpython-312\surprise\model_selection
#       creating build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\algo_base.py -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\baseline_only.py -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\knns.py -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\predictions.py -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\random_pred.py -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\__init__.py -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       running egg_info
#       writing scikit_surprise.egg-info\PKG-INFO
#       writing dependency_links to scikit_surprise.egg-info\dependency_links.txt
#       writing entry points to scikit_surprise.egg-info\entry_points.txt
#       writing requirements to scikit_surprise.egg-info\requires.txt
#       writing top-level names to scikit_surprise.egg-info\top_level.txt
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\arrayscalars.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarrayobject.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ndarraytypes.h won't be automatically included in the manifest: the path must be relative
#       dependency C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\numpy\core\include\numpy\ufuncobject.h won't be automatically included in the manifest: the path must be relative
#       reading manifest file 'scikit_surprise.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*.so' found under directory 'surprise'
#       adding license file 'LICENSE.md'
#       writing manifest file 'scikit_surprise.egg-info\SOURCES.txt'
#       C:\Users\alecp\AppData\Local\Temp\pip-build-env-osac6uuw\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'surprise.prediction_algorithms' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'surprise.prediction_algorithms' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'surprise.prediction_algorithms' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'surprise.prediction_algorithms' to be distributed and are
#               already explicitly excluding 'surprise.prediction_algorithms' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying surprise\similarities.c -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\similarities.pyx -> build\lib.win-amd64-cpython-312\surprise
#       copying surprise\prediction_algorithms\co_clustering.c -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\matrix_factorization.c -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\optimize_baselines.c -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\slope_one.c -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\co_clustering.pyx -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\matrix_factorization.pyx -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\optimize_baselines.pyx -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       copying surprise\prediction_algorithms\slope_one.pyx -> build\lib.win-amd64-cpython-312\surprise\prediction_algorithms
#       running build_ext
#       building 'surprise.similarities' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-surprise
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (scikit-surprise)

# %% [markdown]
# ##  Imports de Base

# %%
# Manipulation de données
import pandas as pd
import numpy as np

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.ensemble import RandomForestClassifier

# Configuration
import warnings
warnings.filterwarnings('ignore')

# Style des graphiques
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print(" Imports réussis !")
# Out:
#  Imports réussis !

# %% [markdown]
# ##  Génération des Données
#
# Exécutez le script de génération de donné

# %%
# Générer les données synthétiques
# %run ../data/generate_data.py
# Out:
# 🔧 Génération des données synthétiques en cours...
#    Utilisateurs : 5000
#    Produits : 1000
#    Interactions : 50000
#
# 👥 Génération des utilisateurs...
#    ✅ 5000 utilisateurs créés
# 📦 Génération des produits...
#    ✅ 1000 produits créés
# 🔗 Génération des interactions...
#    ✅ 50000 interactions créées
# 🔧 Ajout de données complémentaires...
#
# 📊 Statistiques des données générées :
#    Utilisateurs : 5000
#    Produits : 1000
#    Interactions : 50000
#
#    Distribution des interactions :
# interaction_type
# view           34965
# add_to_cart    10034
# purchase        3988
# review          1013
# Name: count, dtype: int64
#
#    Distribution des catégories de produits :
# category
# Accessoires    175
# Ordinateurs    150
# Smartphones    133
# Gaming         128
# Audio          103
# Name: count, dtype: int64
#
# 💾 Sauvegarde des fichiers...
#    ✅ users.csv créé
#    ✅ products.csv créé
#    ✅ interactions.csv créé
#    ✅ metadata.json créé
#
# ✅ Génération terminée avec succès !
#
# 📁 Fichiers créés :
#    - users.csv
#    - products.csv
#    - interactions.csv
#    - metadata.json
#
# 🚀 Vous pouvez maintenant commencer le TP !

# %% [markdown]
# ##  Prochaines Étapes
#
# 1. Les données sont maintenant générées dans le dossier `data/`
# 2. Vous pouvez passer au notebook `01_EDA.ipynb` pour l'analyse exploratoire
# 3. Suivez les instructions du sujet étape par étape
#
#
# Bon courage !
